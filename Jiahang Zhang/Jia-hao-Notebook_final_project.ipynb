# %% [markdown]
# For the question of what is the best neighborhood in Pittsburgh. Our group ultimately decided that the smartest neighborhoods in Pittsburgh were the best neighborhoods. In order to find suitable data to finally determine the only community, we decided to search and summarize data from three aspects. 1. Number of public schools in each Pittsburgh neighborhood 2. Enrollment in public schools in each Pittsburgh neighborhood 3. Graduation rate in each neighborhood. We have discussed whether we should collect information on the number of people in each neighborhood of Pittsburgh and the number of all A+ schools in Pittsburgh. After thinking about it, we think that the number of neighborhoods is very general and we only need the number of students of the corresponding age which already has been collected in The second database. And there is no guarantee that students from A+ schools are necessarily smarter than students from other schools (there is no test score or GPA information to prove it). So we only decided to collect the three datasets mentioned above. I am in charge of collecting data on public school enrollment in various neighborhoods in Pittsburgh. The dataset I am using is called the Enrollment by School and Neighborhood 2020-21 school yr. dataset in the Pittsburgh Public Schools Enrollment by Neighborhood, School, and Feeder Pattern. The metric I measure is student enrollment at schools in various Pittsburgh neighborhoods. By summarizing and analyzing this data set, we can visually see the comparison of enrollment numbers in different communities, and draw conclusions about the smartest communities.

# %%
import matplotlib.pyplot as plt

enrollment = [84, 475, 27, 180, 220, 794, 253, 261, 49, 55, 598, 1169, 125, 1276, 140, 150, 16, 35, 539, 228, 78, 72, 27, 569, 496, 229, 26, 95, 88, 52, 520, 70, 18, 487, 40, 575, 412, 589, 477, 118, 616, 256, 243, 508, 84, 110, 467, 228, 179, 76, 476, 417, 69, 11, 527, 75, 272, 397, 443, 317, 133, 48, 48, 20, 25, 217, 694, 77, 112, 182, 67, 239, 1012, 332, 45, 56, 401, 148, 135, 112, 28, 54, 269, 305, 110]
neighborhoods = ['Allegheny Center', 'Arlington', 'Arlington Heights', 'Banksville', 'Bedford Dwellings', 'Beechview', 'Beltzhoover', 'Bloomfield', 'Bluff', 'Bon Air', 'Brighton Heights', 'Brookline', 'California-Kirkbride', 'Carrick', 'Central Lawrenceville', 'Central Northside', 'Central Oakland', 'Chartiers City', 'Crafton Heights', 'Crawford-Roberts', 'Duquesne Heights', 'East Allegheny', 'East Carnegie', 'East Hills', 'East Liberty', 'Elliott', 'Esplen', 'Fairywood', 'Fineview', 'Friendship', 'Garfield', 'Glen Hazel', 'Golden Triangle', 'Greenfield', 'Hays', 'Hazelwood', 'Highland Park', 'Homewood North', 'Homewood South', 'Homewood West', 'Knoxville', 'Larimer', 'Lincoln Place', 'Lincoln-Lemington-Belmar', 'Lower Lawrenceville', 'Manchester', 'Marshall-Shadeland', 'Middle Hill', 'Morningside', 'Mount Oliver', 'Mount Oliver Borough', 'Mount Washington', 'New Homestead', 'North Oakland', 'Northview Heights', 'Oakwood', 'Overbrook', 'Perry North', 'Perry South', 'Point Breeze', 'Point Breeze North', 'Polish Hill', 'Regent Square', 'Ridgemont', 'Saint Clair', 'Shadyside', 'Sheraden', 'South Oakland', 'South Side Flats', 'South Side Slopes', 'Spring Garden', 'Spring Hill-City View', 'Squirrel Hill South', 'Stanton Heights', 'Summer Hill', 'Swisshelm Park', 'Terrace Village', 'Troy Hill', 'Upper Hill', 'Upper Lawrenceville', 'West End', 'West Oakland', 'Westwood', 'Wilkinsburg Borough', 'Windgap']

fig, ax = plt.subplots()
ax.plot(neighborhoods, enrollment)
ax.set_xlabel('Neighborhoods')
ax.set_ylabel('Enrollment')
ax.set_title('Enrollment numbers for selected neighborhoods')
plt.show()

# %% [markdown]
# In conclusion, the "smartest neighborhood" should be carrick which is the neighborhood has the most number of enrollment.
